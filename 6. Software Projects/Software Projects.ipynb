# %% [markdown]
# <h1> 6.1 Installing libraries <h1>

# %%
 from sklearn.datasets import load_wine

wine = load_wine()
X = wine.data
y = wine.target
feature_names = wine.feature_names

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Find the column index of two features to plot
color_idx = feature_names.index("color_intensity")
proline_idx = feature_names.index("proline")

# Plot the training points
plt.scatter(X[:, color_idx], X[:, proline_idx], c=y, edgecolor="k")
plt.xlabel("Color Intensity")
plt.ylabel("Proline")

plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
import numpy
numpy.__path__
# Out:
# ['/Users/yuxinliu/anaconda3/lib/python3.11/site-packages/numpy']

# %%
import sys
sys.path
# Out:
# ['/Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug',
#  '/Applications/PyCharm.app/Contents/plugins/python/helpers/pydev',
#  '/Users/yuxinliu/Desktop/M2/Python-Learning/5. Testing/DiffusionExercise',
#  '/Users/yuxinliu/Desktop/M2/Python-Learning',
#  '/Users/yuxinliu/anaconda3/lib/python311.zip',
#  '/Users/yuxinliu/anaconda3/lib/python3.11',
#  '/Users/yuxinliu/anaconda3/lib/python3.11/lib-dynload',
#  '',
#  '/Users/yuxinliu/anaconda3/lib/python3.11/site-packages',
#  '/Users/yuxinliu/anaconda3/lib/python3.11/site-packages/aeosa',
#  '/Users/yuxinliu/anaconda3/lib/python3.11/site-packages/setuptools/_vendor']

# %% [markdown]
# <h1> 6.2 Managing Dependencies <h1>

# %% [markdown]
# <h1> 6.3 Python outside the notebook <h1>

# %%
greet("James", "Hetherington")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 greet("James", "Hetherington")
#
# NameError: name 'greet' is not defined

# %%
import greeter
print(greeter.greet("James", "Hetherington"))
# Out:
# Hey, James Hetherington

# %%
from greeter import greet
print(greet("James", "Hetherington"))
# Out:
# Hey, James Hetherington

# %%
from glob import glob
glob("*.py") + glob("*.ipynb")
# Out:
# ['greeter.py', 'Software Projects.ipynb']

# %% [markdown]
# <h1> 6.4 Packaging <h1>

# %%
import os

files = ["greeter.py", "command.py"]
for f in files:
    if os.path.exists(f):
        os.remove(f)

# %% [markdown]
# <h1> 6.5 Documentation <h1>

# %% [markdown]
# <h1> 6.6 Software Project Management <h1>

# %% [markdown]
# <h1> 6.7 Software Licensing <h1>

# %% [markdown]
# <h1> 6.8 Managing software issues <h1>

# %% [markdown]
# <h1> 6.9 Exercise: Packaging Troll Treasure <h1>
